# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
df=pd.read_csv('./Downloads/netflix_ds.csv')

# %%
df.head()
# Out:
#   show_id     type title         director  \
# 0      s1    Movie   NaN  Kirsten Johnson
# 1      s2  TV Show   NaN              NaN
# 2      s3  TV Show   NaN  Julien Leclercq
# 3      s4  TV Show   NaN              NaN
# 4      s5  TV Show   NaN              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# 3  24-Sep-21          2021  TV-MA   1 Season
# 4  24-Sep-21          2021  TV-MA  2 Seasons
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8796 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False   True     False   True    False       False
# 1       False  False   True      True  False    False       False
# 2       False  False   True     False  False     True       False
# 3       False  False   True      True   True     True       False
# 4       False  False   True      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df.isnull().value_counts()
# Out:
# show_id  type   title  director  cast   country  date_added  release_year  rating  duration  listed_in  description
# False    False  False  False     False  False    False       False         False   False     False      False          5329
#                        True      False  False    False       False         False   False     False      False          1956
#                        False     True   False    False       False         False   False     False      False           414
#                                  False  True     False       False         False   False     False      False           361
#                        True      False  True     False       False         False   False     False      False           311
#                                  True   False    False       False         False   False     False      False           256
#                                         True     False       False         False   False     False      False            94
# ...

# %%
#The preceding command shows that the Location 1 column has 11 instances of
#missing values. These missing values can be handled by either removing the rows
#with the missing values or replacing it with some values.

# %%
df.fillna({"title": "No Title"}, inplace = True)
df
# Out:
#      show_id     type        title         director  \
# 0         s1    Movie     No Title  Kirsten Johnson
# 1         s2  TV Show     No Title              NaN
# 2         s3  TV Show     No Title  Julien Leclercq
# 3         s4  TV Show     No Title              NaN
# 4         s5  TV Show     No Title              NaN
# ...      ...      ...          ...              ...
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %%
df["director"].fillna("No Director", inplace = True)
# Out:
# C:\Users\marke\AppData\Local\Temp\ipykernel_33776\1584591460.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["director"].fillna("No Director", inplace = True)

# %%
df.fillna({"director": "No Director"}, inplace = True)
df
# Out:
#      show_id     type        title         director  \
# 0         s1    Movie     No Title  Kirsten Johnson
# 1         s2  TV Show     No Title      No Director
# 2         s3  TV Show     No Title  Julien Leclercq
# 3         s4  TV Show     No Title      No Director
# 4         s5  TV Show     No Title      No Director
# ...      ...      ...          ...              ...
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb      No Director
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %%
df.fillna({"cast": "No Cast"}, inplace = True)
df
# Out:
#      show_id     type        title         director  \
# 0         s1    Movie     No Title  Kirsten Johnson
# 1         s2  TV Show     No Title      No Director
# 2         s3  TV Show     No Title  Julien Leclercq
# 3         s4  TV Show     No Title      No Director
# 4         s5  TV Show     No Title      No Director
# ...      ...      ...          ...              ...
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb      No Director
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               No Cast  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %%
df.fillna({"country": "No Country"}, inplace = True)
df
# Out:
#      show_id     type        title         director  \
# 0         s1    Movie     No Title  Kirsten Johnson
# 1         s2  TV Show     No Title      No Director
# 2         s3  TV Show     No Title  Julien Leclercq
# 3         s4  TV Show     No Title      No Director
# 4         s5  TV Show     No Title      No Director
# ...      ...      ...          ...              ...
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb      No Director
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               No Cast  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     No Country
# ...

# %%
df.fillna({"date_added": "No Date"}, inplace = True)
df
# Out:
#      show_id     type        title         director  \
# 0         s1    Movie     No Title  Kirsten Johnson
# 1         s2  TV Show     No Title      No Director
# 2         s3  TV Show     No Title  Julien Leclercq
# 3         s4  TV Show     No Title      No Director
# 4         s5  TV Show     No Title      No Director
# ...      ...      ...          ...              ...
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb      No Director
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               No Cast  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     No Country
# ...

# %%
df.fillna({"rating": "No Rating"}, inplace = True)
df
# Out:
#      show_id     type        title         director  \
# 0         s1    Movie     No Title  Kirsten Johnson
# 1         s2  TV Show     No Title      No Director
# 2         s3  TV Show     No Title  Julien Leclercq
# 3         s4  TV Show     No Title      No Director
# 4         s5  TV Show     No Title      No Director
# ...      ...      ...          ...              ...
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb      No Director
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               No Cast  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     No Country
# ...

# %%
df.fillna({"duration": "No Duration"}, inplace = True)
df
# Out:
#      show_id     type        title         director  \
# 0         s1    Movie     No Title  Kirsten Johnson
# 1         s2  TV Show     No Title      No Director
# 2         s3  TV Show     No Title  Julien Leclercq
# 3         s4  TV Show     No Title      No Director
# 4         s5  TV Show     No Title      No Director
# ...      ...      ...          ...              ...
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb      No Director
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               No Cast  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     No Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False  False    False       False
# 1       False  False  False     False  False    False       False
# 2       False  False  False     False  False    False       False
# 3       False  False  False     False  False    False       False
# 4       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False     False  False    False       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df.head(30)
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                                           No Title
# 1       s2  TV Show                                           No Title
# 2       s3  TV Show                                           No Title
# 3       s4  TV Show                                           No Title
# 4       s5  TV Show                                           No Title
# 5       s6  TV Show                                           No Title
# 6       s7    Movie                                           No Title
# 7       s8    Movie                                           No Title
# 8       s9  TV Show                                           No Title
# 9      s10    Movie                                           No Title
# 10     s11  TV Show                                           No Title
# 11     s12  TV Show                                   Bangkok Breaking
# ...
